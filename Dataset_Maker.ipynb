# %% [markdown]
# # 📊 Dataset Maker by Hollowstrawberry
#
# This is based on the work of [Kohya-ss](https://github.com/kohya-ss/sd-scripts) and [Linaqruf](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb). Thank you!

# %% [markdown]
# ### ⭕ Disclaimer
# The purpose of this document is to research bleeding-edge technologies in the field of machine learning.
# Please read and follow the [Google Colab guidelines](https://research.google.com/colaboratory/faq.html) and its [Terms of Service](https://research.google.com/colaboratory/tos_v3.html).

# %% [markdown]
# | |GitHub|🇬🇧 English|🇪🇸 Spanish|
# |:--|:-:|:-:|:-:|
# | 🏠 **Homepage** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab) | | |
# | 📊 **Dataset Maker** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Dataset_Maker.ipynb) |
# | ⭐ **Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Lora_Trainer.ipynb) |
# | 🌟 **XL Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) |  |
# | 🌟 **Legacy XL Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL_Legacy.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL_Legacy.ipynb) |  |

# %%
import os
from IPython import get_ipython
from IPython.display import display, Markdown

COLAB = True

if COLAB:
  from google.colab.output import clear as clear_output
else:
  from IPython.display import clear_output

#@title ## 🚩 Start Here

#@markdown ### 1️⃣ Setup
#@markdown This cell will load some requirements and create the necessary folders in your Google Drive. <p>
#@markdown Your project name can't contain spaces but it can contain a single / to make a subfolder in your dataset.
project_name = "STYLEMuneshiro" #@param {type:"string"}
project_name = project_name.strip()
#@markdown The folder structure doesn't matter and is purely for comfort. Make sure to always pick the same one. I like organizing by project.
folder_structure = "Organize by project (MyDrive/Loras/project_name/dataset)" #@param ["Organize by category (MyDrive/lora_training/datasets/project_name)", "Organize by project (MyDrive/Loras/project_name/dataset)"]

if not project_name or any(c in project_name for c in " .()\"'\\") or project_name.count("/") > 1:
  print("Please write a valid project_name.")
else:
  if COLAB and not os.path.exists('/content/drive'):
    from google.colab import drive
    print("📂 Connecting to Google Drive...")
    drive.mount('/content/drive')

  project_base = project_name if "/" not in project_name else project_name[:project_name.rfind("/")]
  project_subfolder = project_name if "/" not in project_name else project_name[project_name.rfind("/")+1:]

  root_dir = "/content" if COLAB else "~/Loras"
  deps_dir = os.path.join(root_dir, "deps")

  if "/Loras" in folder_structure:
    main_dir      = os.path.join(root_dir, "drive/MyDrive/Loras") if COLAB else root_dir
    config_folder = os.path.join(main_dir, project_base)
    images_folder = os.path.join(main_dir, project_base, "dataset")
    if "/" in project_name:
      images_folder = os.path.join(images_folder, project_subfolder)
  else:
    main_dir      = os.path.join(root_dir, "drive/MyDrive/lora_training") if COLAB else root_dir
    config_folder = os.path.join(main_dir, "config", project_name)
    images_folder = os.path.join(main_dir, "datasets", project_name)

  for dir in [main_dir, deps_dir, images_folder, config_folder]:
    os.makedirs(dir, exist_ok=True)

  print(f"✅ Project {project_name} is ready!")
  step1_installed_flag = True
# Out:
# 📂 Connecting to Google Drive...
# Mounted at /content/drive
# ✅ Project STYLEMuneshiro is ready!

# %%
if "step1_installed_flag" not in globals():
  raise Exception("Please run step 1 first!")

import json
import time
from urllib.request import urlopen, Request

#@markdown ### 2️⃣ Scrape images from Gelbooru

#@markdown We will grab images from the popular anime gallery [Gelbooru](https://gelbooru.com/). Images are sorted by tags, including poses, scenes, character traits, character names, artists, etc. <p>
#@markdown * If you instead want to use your own images, upload them to your Google Drive's `Loras/project_name/dataset` folder.
#@markdown * If you instead want to download screencaps of anime episodes, try [this other colab by another person](https://colab.research.google.com/drive/1oBSntB40BKzNmKceXUlkXzujzdQw-Ci7). It's more complicated though.

#@markdown Up to 1000 images may be downloaded by this step in just one minute. Don't abuse it. <p>
#@markdown Your target tags should include the relevant tags for your character/concept/artstyle, and exclude undesired tags (for example, explicit images may affect learning).
#@markdown Separate words with underscores, separate tags with spaces, and use - to exclude a tag. You can also include a minimum score: `score:>10`
tags = "muneshiro_(hitsuji_kikaku)" #@param {type:"string"}
##@markdown If an image is bigger than this resolution a smaller version will be downloaded instead.
max_resolution = 3072 #param {type:"slider", min:1024, max:8196, step:1024}
##@markdown Posts with a parent post are often minor variations of the same image.
include_posts_with_parent = True #param {type:"boolean"}

tags = tags.replace(" ", "+")\
           .replace("(", "%28")\
           .replace(")", "%29")\
           .replace(":", "%3a")\
           .replace("&", "%26")\

url = "https://gelbooru.com/index.php?page=dapi&json=1&s=post&q=index&limit=100&tags={}".format(tags)
user_agent = "Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; Googlebot/2.1; +http://www.google.com/bot.html) Chrome/93.0.4577.83 Safari/537.36"
limit = 100 # hardcoded by gelbooru
total_limit = 1000 # you can edit this if you want but I wouldn't recommend it
supported_types = (".png", ".jpg", ".jpeg")

def ubuntu_deps():
  print("🏭 Installing dependencies...\n")
  # !apt -y install aria2
  return not get_ipython().__dict__['user_ns']['_exit_code']

if "step2_installed_flag" not in globals():
  if ubuntu_deps():
    clear_output()
    step2_installed_flag = True
  else:
    print("❌ Error installing dependencies, attempting to continue anyway...")

def get_json(url):
  with urlopen(Request(url, headers={"User-Agent": user_agent})) as page:
    return json.load(page)

def filter_images(data):
  return [p["file_url"] if p["width"]*p["height"] <= max_resolution**2 else p["sample_url"]
          for p in data["post"]
          if (p["parent_id"] == 0 or include_posts_with_parent)
          and p["file_url"].lower().endswith(supported_types)]

def download_images():
  data = get_json(url)
  count = data["@attributes"]["count"]

  if count == 0:
    print("📷 No results found")
    return

  print(f"🎯 Found {count} results")
  test_url = "https://gelbooru.com/index.php?page=post&s=list&tags={}".format(tags)
  display(Markdown(f"[Click here to open in browser!]({test_url})"))
  print (f"🔽 Will download to {images_folder.replace('/content/drive/', '')} (A confirmation box should appear below, otherwise run this cell again)")
  inp = input("❓ Enter the word 'yes' if you want to proceed with the download: ")

  if inp.lower().strip() != 'yes':
    print("❌ Download cancelled")
    return

  print("📩 Grabbing image list...")

  image_urls = set()
  image_urls = image_urls.union(filter_images(data))
  for i in range(total_limit // limit):
    count -= limit
    if count <= 0:
      break
    time.sleep(0.1)
    image_urls = image_urls.union(filter_images(get_json(url+f"&pid={i+1}")))

  scrape_file = os.path.join(config_folder, f"scrape_{project_subfolder}.txt")
  with open(scrape_file, "w") as f:
    f.write("\n".join(image_urls))

  print(f"🌐 Saved links to {scrape_file}\n\n🔁 Downloading images...\n")
  old_img_count = len([f for f in os.listdir(images_folder) if f.lower().endswith(supported_types)])

  os.chdir(images_folder)
  # !aria2c --console-log-level=warn -c -x 16 -k 1M -s 16 -i {scrape_file}

  new_img_count = len([f for f in os.listdir(images_folder) if f.lower().endswith(supported_types)])
  print(f"\n✅ Downloaded {new_img_count - old_img_count} images.")

download_images()
# Out:
# 🎯 Found 140 results
# [Click here to open in browser!](https://gelbooru.com/index.php?page=post&s=list&tags=muneshiro_%28hitsuji_kikaku%29)
# 🔽 Will download to MyDrive/Loras/STYLEMuneshiro/dataset (A confirmation box should appear below, otherwise run this cell again)
# ❓ Enter the word 'yes' if you want to proceed with the download: yes
# 📩 Grabbing image list...
# 🌐 Saved links to /content/drive/MyDrive/Loras/STYLEMuneshiro/scrape_STYLEMuneshiro.txt
#
# 🔁 Downloading images...
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3e299e|OK  |   4.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/fd6824284a4e7a71f712a0e67d567d54.jpg
# a7f85c|OK  |   7.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/7a55141c3ffdec1022f314bd226869ef.jpg
# e4a883|OK  |    12MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/32ef934fbeeae3e8d453ac10105bc388.jpg
# 61a507|OK  |   5.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/75d235fbbfbe59c6003c75e7261884b7.jpg
# 3f9280|OK  |    31MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/0da395c5c15d4419b0220a7582c760aa.jpg
# 93a346|OK  |    26MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/ff724c1d686941fb5247fac49415d911.jpg
# 1945ad|OK  |   9.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/98dcde572f9f8af9373aa048ebca6601.jpg
# 560854|OK  |   9.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/8b5939399e34939727f8565b0c08102c.jpg
# 440a78|OK  |   2.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/377f02daf6ea285ebebb7bada49bc951.jpg
# 8717d5|OK  |   4.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/7fdeaee95d895dbb22b67bbb0fac8507.jpg
# b28cba|OK  |    33MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/6005e2e6082c0fc00f67f7b022de97f1.jpg
# 00d181|OK  |    17MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/1512e9c73c7194661f2ec772e29f9035.jpg
# 74c636|OK  |   1.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/b9e95d51ba9ab62735043140df39cccc.jpg
# 28fcb5|OK  |   3.7MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/d58a6513a02ca9ea3eb800bd977b9a4c.jpg
# d02dd8|OK  |   4.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/39b29ce277983d0929a598fe544231dd.jpg
# cd4e2f|OK  |   4.9MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/7462628def434f5ed35a89d8e5b441f9.jpg
# f8d477|OK  |   6.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/d2bba59ae1709b03f18ba9b64f66a7e7.jpg
# 9208c4|OK  |   1.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/c27628dfd66581ba0b00b610dd32acc5.jpg
# e7851c|OK  |   3.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/e6a9c975f7bb8e532d1b412a2c2e5a46.jpg
# 258d67|OK  |   5.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/6a8bb98f897ababf1f73a6fbde3aa579.jpg
# 4ee529|OK  |   5.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/e159dd12d2a29ab43e2d4ad35db88176.jpg
# dcbb57|OK  |   5.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/005fc5ae02b697371e19791dafbc5fe8.jpeg
# ec4dff|OK  |    11MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/eb536bfc26dee49e31ea27b5ed3ac509.jpg
# 472308|OK  |   1.5MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/a2570e399614c8b48195bcdf3c4dfa9d.jpg
# c5481b|OK  |   7.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/12246f2bd90385d0dcc424b4f2fbe36b.jpg
# 6316e6|OK  |    16MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/dc8bcfa7013c4bb36904b587b18f3d42.jpg
# 46bc74|OK  |   7.5MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/98f4bab521390790ef47a182c4a63c16.jpg
# 7b33eb|OK  |    23MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/9c38a5ef7c89312c3afdf06f4a70aac6.jpg
# 3a2fab|OK  |    19MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/b3628fa83d3ae0d22b7a06a7fbf40403.jpg
# 76179a|OK  |   0.9MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/87753202f9ae5da6415322b8d3a6e4ac.jpg
# 10d21b|OK  |   1.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/8061647624f99f7fd21b4c9497ff4248.jpg
# eefd7b|OK  |   3.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/17580be0fb0bd0674214f8d9d3735bff.jpg
# 5d4790|OK  |   4.9MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/12891229674743bd5f53a9ea97aa6113.jpg
# faaae9|OK  |    21MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/12507047d2a3ab69fd6a75c1892fb2c2.jpg
# 47f3b0|OK  |   692KiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/6821a7b8b95999ddd3e93a094b39394a.jpg
# 2e52c3|OK  |   4.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/81f9d92458520bcee19f148ed3cb188f.jpg
# 90a13c|OK  |   6.4MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/26021c699332b6654386a1354769bc4c.jpg
# 0e9a7c|OK  |   6.5MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/17522287468f114ffeae6f2007649e01.png
# 26b52b|OK  |    22MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/28b343e6395d6080e72c09adc4310472.jpg
# 7679a7|OK  |    11MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/ae8f02a36501c9e354af7c33cc7a7904.jpg
# 1a60d1|OK  |   3.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/11905017714466e98ec88cd422391872.jpg
# 036491|OK  |   5.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/93a2b8df63394a7a8c0a15d5d3b6c04b.jpg
# efbb41|OK  |    12MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/7a1e82f259124e2e887788f74adb9e0d.jpg
# e4b319|OK  |    14MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/f5309eb2149e37414f5acc524ccc1581.jpg
# 36b2ea|OK  |    28MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/51da05a18350cee9673a7bc4f8b253ef.jpg
# 73fa4c|OK  |   2.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/d76ad556a59ee4a035fb464568474de9.png
# f7ba09|OK  |   2.6MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/94c9cac32313008d6a6ec2d177e7bb03.jpg
# 3d9ac2|OK  |   3.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/617596b3762ab9ba19f4fa5a1684bb5f.jpg
# b57d45|OK  |   8.5MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/d07e046169db8ef858fce5bd0dc84299.jpg
# 19bbcb|OK  |   5.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/d5f1f95fb15fa7919c594ce1e0d53a13.jpg
# 405085|OK  |   1.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/cede72b3d5485e6d519fd56791384758.jpg
# e94474|OK  |   2.9MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/ac58e03150bbdda9b10e8357d1979950.jpg
# 760220|OK  |   2.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/4a747e74f3bee413db450126a9577b42.jpg
# 55c549|OK  |    10MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/0a5c9a88e61a1fd5b54f4da579b9e62a.jpg
# 78df9a|OK  |    19MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/55c3e8958e47547163701a8506c6e9c3.jpg
# add21a|OK  |   1.6MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/b61ca95cd12d79a6b2f1b019045ac2d7.jpg
# ef139a|OK  |   1.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/42de36942acf48e9d8c126ffbd723087.jpg
# 7560e3|OK  |   2.4MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/37a5ed2a08a7deb79b5fc2d5922002ee.png
# dda81d|OK  |   2.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/2dcc783961b90f5bceacda3f1a2036bd.jpg
# 6e1f73|OK  |   2.4MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/6a43efeaabfbb8631e6fc6f90c03afa7.jpg
# 931045|OK  |    33MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/f9ecb7bc406365fcacfa6b2712551048.jpg
# 9f73dc|OK  |   7.7MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/bd8dd84120118847e4f8811c1ad39e41.png
# 10bcfa|OK  |   3.9MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/dc33f46b5f419d33c0513e2add558ed7.jpg
# e99e70|OK  |   5.4MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/0d0110834a875be8159d967457927802.jpg
# 641859|OK  |   7.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/b1ba975a64a129c23c1ad2685ae94812.jpg
# f2baea|OK  |    34MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/6ad83a8e567dd45654e4a8de8e3c75a6.jpg
# 87c23f|OK  |    31MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/fc60bbe12f91b0b1bb7fa590f3ecef4c.jpg
# 55cb54|OK  |    12MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/7d6e970a77539cbc58298eabbe1b4831.jpg
# 2f6706|OK  |   7.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/f15fb88ef9dc2e2bee847ecd47e5a41b.jpg
# 2468fe|OK  |   6.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/eae54cc5fc7ada9ba5c8f529024579da.jpg
# e9253b|OK  |    15MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/fd80eebd74006db9f106f2730d751fdf.jpg
# 83f70c|OK  |   8.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/bd98797875793eff54fc8f774a074f6d.jpg
# 782144|OK  |    43MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/5640d2a6429a38f23a770dd3eeab795b.jpg
# c47ba1|OK  |    22MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/c929293dfc4fec0a302deb241920db65.jpg
# 54957d|OK  |   3.4MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/f0ed1289048365f92f66bef7c0fdce19.jpg
# 8b735d|OK  |    10MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/3e9eabe48514ffccdfe1e95e1e8139a2.jpg
# fa01c0|OK  |   8.6MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/4ca94073fd7178cdbebf16a954d45315.jpg
# 88ede5|OK  |   7.7MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/704ba631f8f477bfe7a7f19c0d5d9eb6.jpg
# f303ee|OK  |    16MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/0fbc6fb03f47394ed5e4044c99003e6e.jpg
# 611a09|OK  |   6.8MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/93c3d4120698cc833617d574c5bd2385.jpg
# 67b2bf|OK  |   8.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/07428a913ef0fab5a0459a6f94f70235.jpg
# 5d1150|OK  |   5.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/2b3939f1a14fee204f4eaa994ab0e8b9.jpg
# 88e74f|OK  |   8.7MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/4380cce9e5e987aeeabe418d77345267.jpg
# 101174|OK  |    27MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/6634c72a3d88015ef531bd4e6ed837aa.jpg
# a1821d|OK  |    40MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/4879b6eab073ec3f7691175f4c034fe6.jpg
# 425872|OK  |   8.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/dd4f41349e1205007b724a6d2b465f82.jpg
# c35d09|OK  |   5.7MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/50b4dd540861017cdf8ef07b442dd0e5.jpg
# fbe05f|OK  |   5.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/d8ca58e7f7dea8ffe9c2f94802e590f4.jpg
# 450e7c|OK  |   6.8MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/787ddea814660f4710318d0d73ad4fc7.jpg
# ca7bd9|OK  |   7.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/ba1f2d7f2b335b02556081cb85b5ff93.jpg
# 4326b8|OK  |    18MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/139cb2304344eb3850916e64df431d2f.jpg
# 5829b7|OK  |   3.9MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/3a08770b8758edf83d16ee4c6100b6dc.jpg
# dde485|OK  |    21MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/8dec5dc668207fed255f32b71c24d0f0.jpg
# 2b2c5c|OK  |    11MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/1da7ad117c7f5e4f772846b97f11935f.jpg
# 83f319|OK  |   8.7MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/5e2105cbfc34a6de4defce88e8b21c46.jpg
# e67355|OK  |    29MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/d8338329e111d9c1e9751ad1cda410bd.jpg
# b72d26|OK  |   1.9MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/dc9e100a42462899def1657eeb7fd272.jpg
# 07ebe7|OK  |   6.5MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/85d5fab4027c9cb2e0f01da4c3e46c80.jpg
# 3d0133|OK  |    19MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/ae30c11c8b550270937bad7b80f359a0.jpg
# 71d058|OK  |   3.6MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/ae8d3ab54b166453e7db9ce5ff168329.jpg
# 033f50|OK  |   2.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/5d8ba10bf6fb68cffc29dc848046f4bf.jpg
# f843a6|OK  |   2.6MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/a08c4f89bcf60f10b7b6466ef5f405b7.jpg
# 57a0c8|OK  |   5.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/8eef6ffd86051dc259a1de40e4fe4dff.jpeg
# 268022|OK  |    11MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/b524f18f5cb772a9d123c005f6b81aa7.jpg
# d7e8a9|OK  |   7.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/9abe2bc33987b6e8f449a77898aeef76.jpg
# 9b84ee|OK  |   5.9MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/835b7ef200d7a76e2bafabb8c61d87eb.jpg
# 5e9644|OK  |   6.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/5e8dcc9fc7175aad28a5582662608044.jpg
# 326beb|OK  |   8.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/1b2efdba4cfa5c75bf3419a3866315f0.png
# 1d5bed|OK  |   7.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/a86bf2cfa1620e0db47a4e4c0bea1dd0.jpg
# 2ad38e|OK  |    13MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/aa7ba07d2010a77515198363473f7506.jpg
# d25d5c|OK  |   3.8MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/4bc40cb9c2f1c9f035df143598230982.jpg
# b8959a|OK  |    32MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/ab95cb77dcdda9b7a205c6db0d069fd3.jpg
# 0d1cfe|OK  |    10MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/05d891d0e3fdeb7d0e6ee0f0f027957e.jpg
# 08384e|OK  |    11MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/97da86d2a6baad00cab86cd0cdcd44fc.jpg
# 6e1bd9|OK  |    32MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/50a59923a54d0c5ef8fef01f294c99f1.jpeg
# 5ab941|OK  |   2.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/358535d6572b9b6f54b794b4bd18f463.jpg
# db04d3|OK  |    11MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/1c1162239b92ced4a4550716781f23cc.jpeg
# 74e62a|OK  |   6.5MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/d2e2cd9413efd512383a9eb46f5fdf5f.jpeg
# 57f19b|OK  |    26MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/7fbc531258219cf006195950d90f573f.jpg
# 6114b9|OK  |   7.8MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/5cfea60ef4f8d86fd717cd44d9dcebec.jpg
# 13b267|OK  |    12MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/bd0c8ffe87a5d3e70ea6aaaa9c8d72c4.jpg
# 5ae444|OK  |   7.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/3db0d7f9e917974a18e516b958397f7c.jpg
# fdfa15|OK  |   4.8MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/ad76003bab5b318896cd58ca7605544b.jpg
# 87c2b4|OK  |   5.6MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/7e922eae694c2c239f81044b35dfb441.jpg
# 56095b|OK  |   1.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/aba4039154b51cf36e3def1c8236e30a.jpg
# f65749|OK  |   6.3MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/cf24e9c4f6b975cd0e30fe51d39613e1.jpg
# 2cfb7c|OK  |   4.4MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/db436171ad5df49a00c52c9ab800f18b.png
# 243d9b|OK  |   5.7MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/c16968fd16076ca4805233109260f743.jpg
# 3f6e81|OK  |   9.5MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/9ed67d9f37776069bc5a0c59dcbfca33.jpg
# 83e3d7|OK  |   2.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/16202d452e070ae761eaec511e4d22b7.jpg
# 09d7c6|OK  |   2.0MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/984c8c6d64718403cda77ee15275ac12.jpg
# 115049|OK  |    12MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/5ee38765f5a8d09830c8ae9e6d5099be.jpg
# 0a5c8b|OK  |   6.2MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/17b4e489d19247cc887913c41d01879e.jpg
# c28d13|OK  |    43MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/8b44b7219a401cc14424d3dc9c1c5e2e.jpg
# 1c128b|OK  |    10MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/69f11cedb3acbc918d2a24236a8cab02.jpg
# bad899|OK  |   6.1MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/5644bff74c3b577c859472eb9b68d1d0.jpg
# 43331a|OK  |   9.8MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/4be1fef49f1ee80446ca92c2bc0e2e99.jpg
# 22c839|OK  |    22MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/9bcbfa3b2251add3cf4a61f3d8631a1e.jpg
# 47e301|OK  |    11MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/5f3edde0a3155617cc3191c1661790d4.jpg
# f8dc3c|OK  |   2.6MiB/s|/content/drive/MyDrive/Loras/STYLEMuneshiro/dataset/f3704ad8a72e72b465436dba80d79cc8.jpg
#
# Status Legend:
# (OK):download completed.
#
# ✅ Downloaded 140 images.

# %%
if "step1_installed_flag" not in globals():
  raise Exception("Please run step 1 first!")

#@markdown ### 3️⃣ Curate your images
#@markdown We will find duplicate images with the FiftyOne AI, and mark them with `delete`. <p>
#@markdown Then, an interactive area will appear below this cell that lets you visualize all your images and manually mark with `delete` to the ones you don't like. <p>
#@markdown If the interactive area appears blank for over a minute, try enabling cookies and removing tracking protection for the Google Colab website, as they may break it.
#@markdown Regardless, you can save your changes by sending Enter in the input box above the interactive area.<p>
#@markdown This is how similar 2 images must be to be marked for deletion. I recommend 0.97 to 0.99:
similarity_threshold = 0.985 #@param {type:"number"}
#@markdown To open the interactive area in a new tab INSTEAD of below, you need an ngrok account.
open_in_new_tab = False #@param {type:"boolean"}
ngrok_token = "" #@param {type:"string"}


os.chdir(root_dir)
model_name = "clip-vit-base32-torch"
supported_types = (".png", ".jpg", ".jpeg")
img_count = len(os.listdir(images_folder))
batch_size = min(250, img_count)

if "step3_installed_flag" not in globals():
  print("🏭 Installing dependencies...\n")
  # !pip -q install fiftyone ftfy pyngrok
  # !pip -q install fiftyone-db-ubuntu2204
  if not get_ipython().__dict__['user_ns']['_exit_code']:
    clear_output()
    step3_installed_flag = True
  else:
    print("❌ Error installing dependencies, attempting to continue anyway...")

os.environ["FIFTYONE_SERVER"] = "0"
import numpy as np
import fiftyone as fo
import fiftyone.zoo as foz
from fiftyone import ViewField as F
from sklearn.metrics.pairwise import cosine_similarity
from pyngrok import ngrok, conf
from portpicker import pick_unused_port

non_images = [f for f in os.listdir(images_folder) if not f.lower().endswith(supported_types)]
if non_images:
  print(f"💥 Error: Found non-image file {non_images[0]} - This program doesn't allow it. Sorry! Use the Extras at the bottom to clean the folder.")
elif img_count == 0:
  print(f"💥 Error: No images found in {images_folder}")
else:
  print("\n💿 Analyzing dataset...\n")
  dataset = fo.Dataset.from_dir(images_folder, dataset_type=fo.types.ImageDirectory)
  model = foz.load_zoo_model(model_name)
  embeddings = dataset.compute_embeddings(model, batch_size=batch_size)

  batch_embeddings = np.array_split(embeddings, batch_size)
  similarity_matrices = []
  max_size_x = max(array.shape[0] for array in batch_embeddings)
  max_size_y = max(array.shape[1] for array in batch_embeddings)

  for i, batch_embedding in enumerate(batch_embeddings):
    similarity = cosine_similarity(batch_embedding)
    #Pad 0 for np.concatenate
    padded_array = np.zeros((max_size_x, max_size_y))
    padded_array[0:similarity.shape[0], 0:similarity.shape[1]] = similarity
    similarity_matrices.append(padded_array)

  similarity_matrix = np.concatenate(similarity_matrices, axis=0)
  similarity_matrix = similarity_matrix[0:embeddings.shape[0], 0:embeddings.shape[0]]

  similarity_matrix = cosine_similarity(embeddings)
  similarity_matrix -= np.identity(len(similarity_matrix))

  dataset.match(F("max_similarity") > similarity_threshold)
  dataset.tags = ["delete", "has_duplicates"]

  id_map = [s.id for s in dataset.select_fields(["id"])]
  samples_to_remove = set()
  samples_to_keep = set()

  for idx, sample in enumerate(dataset):
    if sample.id not in samples_to_remove:
      # Keep the first instance of two duplicates
      samples_to_keep.add(sample.id)

      dup_idxs = np.where(similarity_matrix[idx] > similarity_threshold)[0]
      for dup in dup_idxs:
          # We kept the first instance so remove all other duplicates
          samples_to_remove.add(id_map[dup])

      if len(dup_idxs) > 0:
          sample.tags.append("has_duplicates")
          sample.save()
    else:
      sample.tags.append("delete")
      sample.save()

  clear_output()

  sidebar_groups = fo.DatasetAppConfig.default_sidebar_groups(dataset)
  for group in sidebar_groups[1:]:
    group.expanded = False
  dataset.app_config.sidebar_groups = sidebar_groups
  dataset.save()

  os.environ["FIFTYONE_SERVER"] = "1"
  port = pick_unused_port()
  session = fo.launch_app(dataset, port=port, auto=not open_in_new_tab)
  if open_in_new_tab:
    conf.get_default().auth_token = ngrok_token
    public_url = ngrok.connect(port).public_url
    print(f"🟢 Session open at {public_url}")

  print("❗ Wait a minute for the session to load. If it doesn't, read above.")
  print("❗ When it's ready, you'll see a grid of your images.")
  print("❗ On the left side enable \"sample tags\" to visualize the images marked for deletion.")
  print("❗ You can mark your own images with the \"delete\" label by selecting them and pressing the tag icon at the top.")
  input("⭕ When you're done, enter something here to save your changes: ")

  print("💾 Saving...")

  marked = [s for s in dataset if "delete" in s.tags]
  dataset.delete_samples(marked)
  previous_folder = images_folder[:images_folder.rfind("/")]
  dataset.export(export_dir=os.path.join(images_folder, project_subfolder), dataset_type=fo.types.ImageDirectory)

  temp_suffix = "_temp"
  # !mv {images_folder} {images_folder}{temp_suffix}
  # !mv {images_folder}{temp_suffix}/{project_subfolder} {images_folder}
  # !rm -r {images_folder}{temp_suffix}

  session.refresh()
  fo.close_app()
  clear_output()

  print(f"\n✅ Removed {len(marked)} images from dataset. You now have {len(os.listdir(images_folder))} images.")

# %%
if "step1_installed_flag" not in globals():
  raise Exception("Please run step 1 first!")

#@markdown ### 4️⃣ Tag your images
#@markdown We will be using AI to automatically tag your images, specifically [Waifu Diffusion](https://huggingface.co/SmilingWolf/wd-v1-4-swinv2-tagger-v2) in the case of anime and [BLIP](https://huggingface.co/spaces/Salesforce/BLIP) in the case of photos.
#@markdown Giving tags/captions to your images allows for much better training. This process should take a couple minutes. <p>
method = "Anime tags" #@param ["Anime tags", "Photo captions"]
#@markdown **Anime:** The threshold is the minimum level of confidence the tagger must have in order to include a tag. Lower threshold = More tags. Recommended 0.35 to 0.5
tag_threshold = 0.35 #@param {type:"slider", min:0.0, max:1.0, step:0.01}
blacklist_tags = "bangs, breasts, multicolored hair, two-tone hair, gradient hair, virtual youtuber, parody, style parody, official alternate costume, official alternate hairstyle, official alternate hair length, alternate costume, alternate hairstyle, alternate hair length, alternate hair color" #@param {type:"string"}
#@markdown **Photos:** The minimum and maximum length of tokens/words in each caption.
caption_min = 10 #@param {type:"number"}
caption_max = 75 #@param {type:"number"}

# %env PYTHONPATH=/env/python
os.chdir(root_dir)
kohya = "/content/kohya-trainer"
if not os.path.exists(kohya):
  # !git clone https://github.com/kohya-ss/sd-scripts {kohya}
  os.chdir(kohya)
  # !git reset --hard 9a67e0df390033a89f17e70df5131393692c2a55
  os.chdir(root_dir)

if "tags" in method:
  if "step4a_installed_flag" not in globals() or "step4b_installed_flag" in globals():
    print("\n🏭 Installing dependencies...\n")
    # !pip install accelerate==0.25.0 diffusers[torch]==0.25.0 einops==0.6.0 tensorflow==2.15.0 \
      keras==2.15.0 transformers safetensors huggingface-hub==0.22.0 torchvision albumentations \
      jax==0.4.23 jaxlib==0.4.23 flax==0.7.5
    if not get_ipython().__dict__['user_ns']['_exit_code']:
      clear_output()
      step4a_installed_flag = True
    else:
      print("❌ Error installing dependencies, trying to continue anyway...")

  print("\n🚶‍♂️ Launching program...\n")

  os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
  # %env PYTHONPATH={kohya}
  # !python {kohya}/finetune/tag_images_by_wd14_tagger.py \
    {images_folder} \
    --repo_id=SmilingWolf/wd-v1-4-swinv2-tagger-v2 \
    --model_dir={root_dir} \
    --thresh={tag_threshold} \
    --batch_size=1 \
    --caption_extension=.txt \
    --force_download

  if not get_ipython().__dict__['user_ns']['_exit_code']:
    print("removing underscores and blacklist...")
    blacklisted_tags = [t.strip() for t in blacklist_tags.split(",")]
    from collections import Counter
    top_tags = Counter()
    for txt in [f for f in os.listdir(images_folder) if f.lower().endswith(".txt")]:
      with open(os.path.join(images_folder, txt), 'r') as f:
        tags = [t.strip() for t in f.read().split(",")]
        tags = [t.replace("_", " ") if len(t) > 3 else t for t in tags]
        tags = [t for t in tags if t not in blacklisted_tags]
      top_tags.update(tags)
      with open(os.path.join(images_folder, txt), 'w') as f:
        f.write(", ".join(tags))

    # %env PYTHONPATH=/env/python
    clear_output()
    print(f"📊 Tagging complete. Here are the top 50 tags in your dataset:")
    print("\n".join(f"{k} ({v})" for k, v in top_tags.most_common(50)))


else: # Photos
  if "step4b_installed_flag" not in globals() or "step4a_installed_flag" in globals():
    print("\n🏭 Installing dependencies...\n")
    # !pip install timm==1.0.14 fairscale==0.4.13 transformers==4.26.0 requests \
      accelerate==0.25.0 diffusers[torch]==0.25.0 einops==0.6.0 safetensors \
      jax==0.4.23 jaxlib==0.4.23 flax==0.7.5 huggingface-hub==0.22.0
    if not get_ipython().__dict__['user_ns']['_exit_code']:
      clear_output()
      step4b_installed_flag = True
    else:
      print("❌ Error installing dependencies, trying to continue anyway...")

  print("\n🚶‍♂️ Launching program...\n")

  os.chdir(kohya)
  # %env PYTHONPATH={kohya}
  # !python {kohya}/finetune/make_captions.py \
    {images_folder} \
    --beam_search \
    --max_data_loader_n_workers=2 \
    --batch_size=1 \
    --min_length={caption_min} \
    --max_length={caption_max} \
    --caption_extension=.txt

  if not get_ipython().__dict__['user_ns']['_exit_code']:
    import random
    captions = [f for f in os.listdir(images_folder) if f.lower().endswith(".txt")]
    sample = []
    for txt in random.sample(captions, min(10, len(captions))):
      with open(os.path.join(images_folder, txt), 'r') as f:
        sample.append(f.read())

    os.chdir(root_dir)
    # %env PYTHONPATH=/env/python
    clear_output()
    print(f"📊 Captioning complete. Here are {len(sample)} example captions from your dataset:")
    print("".join(sample))

# %%
if "step1_installed_flag" not in globals():
  raise Exception("Please run step 1 first!")

#@markdown ### 5️⃣ Curate your tags
#@markdown Modify your dataset's tags. You can run this cell multiple times with different parameters. <p>

#@markdown Put an activation tag at the start of every text file. This is useful to make learning better and activate your Lora easier. Set `keep_tokens` to 1 when training.<p>
#@markdown Common tags that are removed such as hair color, etc. will be "absorbed" by your activation tag.
global_activation_tag = "hatsune miku" #@param {type:"string"}
remove_tags = "" #@param {type:"string"}
#@markdown &nbsp;

#@markdown In this advanced section, you can search text files containing matching tags, and replace them with less/more/different tags. If you select the checkbox below, any extra tags will be put at the start of the file, letting you assign different activation tags to different parts of your dataset. Still, you may want a more advanced tool for this.
search_tags = "" #@param {type:"string"}
replace_with = "" #@param {type:"string"}
search_mode = "OR" #@param ["OR", "AND"]
new_becomes_activation_tag = False #@param {type:"boolean"}
#@markdown These may be useful sometimes. Will remove existing activation tags, be careful.
sort_alphabetically = False #@param {type:"boolean"}
remove_duplicates = False #@param {type:"boolean"}

def split_tags(tagstr):
  return [s.strip() for s in tagstr.split(",") if s.strip()]

activation_tag_list = split_tags(global_activation_tag)
remove_tags_list = split_tags(remove_tags)
search_tags_list = split_tags(search_tags)
replace_with_list = split_tags(replace_with)
replace_new_list = [t for t in replace_with_list if t not in search_tags_list]

replace_with_list = [t for t in replace_with_list if t not in replace_new_list]
replace_new_list.reverse()
activation_tag_list.reverse()

remove_count = 0
replace_count = 0

for txt in [f for f in os.listdir(images_folder) if f.lower().endswith(".txt")]:

  with open(os.path.join(images_folder, txt), 'r') as f:
    tags = [s.strip() for s in f.read().split(",")]

  if remove_duplicates:
    tags = list(set(tags))
  if sort_alphabetically:
    tags.sort()

  for rem in remove_tags_list:
    if rem in tags:
      remove_count += 1
      tags.remove(rem)

  if "AND" in search_mode and all(r in tags for r in search_tags_list) \
      or "OR" in search_mode and any(r in tags for r in search_tags_list):
    replace_count += 1
    for rem in search_tags_list:
      if rem in tags:
        tags.remove(rem)
    for add in replace_with_list:
      if add not in tags:
        tags.append(add)
    for new in replace_new_list:
      if new_becomes_activation_tag:
        if new in tags:
          tags.remove(new)
        tags.insert(0, new)
      else:
        if new not in tags:
          tags.append(new)

  for act in activation_tag_list:
    if act in tags:
      tags.remove(act)
    tags.insert(0, act)

  with open(os.path.join(images_folder, txt), 'w') as f:
    f.write(", ".join(tags))

if global_activation_tag:
  print(f"\n📎 Applied new activation tag(s): {', '.join(activation_tag_list)}")
if remove_tags:
  print(f"\n🚮 Removed {remove_count} tags.")
if search_tags:
  print(f"\n💫 Replaced in {replace_count} files.")
print("\n✅ Done! Check your updated tags in the Extras below.")

# %%
#@markdown ### 6️⃣ Ready
#@markdown You should be ready to [train your Lora](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb)!

from IPython.display import Markdown, display
display(Markdown(f"### 🦀 [Click here to open the Lora trainer](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb)"))

# %% [markdown]
# ## *️⃣ Extras

# %%
if "step1_installed_flag" not in globals():
  raise Exception("Please run step 1 first!")

#@markdown ### 📈 Analyze Tags
#@markdown Perhaps you need another look at your dataset.
show_top_tags = 50 #@param {type:"number"}

from collections import Counter
top_tags = Counter()

for txt in [f for f in os.listdir(images_folder) if f.lower().endswith(".txt")]:
  with open(os.path.join(images_folder, txt), 'r') as f:
    top_tags.update([s.strip() for s in f.read().split(",")])

top_tags = Counter(top_tags)
print(f"📊 Top {show_top_tags} tags:")
for k, v in top_tags.most_common(show_top_tags):
  print(f"{k} ({v})")

# %%
#@markdown ### 📂 Unzip dataset
#@markdown It's much slower to upload individual files to your Drive, so you may want to upload a zip if you have your dataset in your computer.
zip = "/content/drive/MyDrive/Loras/example.zip" #@param {type:"string"}
extract_to = "/content/drive/MyDrive/Loras/example/dataset" #@param {type:"string"}

import os, zipfile

if not os.path.exists('/content/drive'):
  from google.colab import drive
  print("📂 Connecting to Google Drive...")
  drive.mount('/content/drive')

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip, 'r') as f:
  f.extractall(extract_to)

print("✅ Done")

# %%
#@markdown ### 🔢 Count datasets
#@markdown Google Drive makes it impossible to count the files in a folder, so this will show you the file counts in all folders and subfolders.
folder = "/content/drive/MyDrive/Loras" #@param {type:"string"}

import os
from google.colab import drive

if not os.path.exists('/content/drive'):
    print("📂 Connecting to Google Drive...\n")
    drive.mount('/content/drive')

tree = {}
exclude = ("_logs", "/output")
for i, (root, dirs, files) in enumerate(os.walk(folder, topdown=True)):
  dirs[:] = [d for d in dirs if all(ex not in d for ex in exclude)]
  images = len([f for f in files if f.lower().endswith((".png", ".jpg", ".jpeg"))])
  captions = len([f for f in files if f.lower().endswith(".txt")])
  others = len(files) - images - captions
  path = root[folder.rfind("/")+1:]
  tree[path] = None if not images else f"{images:>4} images | {captions:>4} captions |"
  if tree[path] and others:
    tree[path] += f" {others:>4} other files"

pad = max(len(k) for k in tree)
print("\n".join(f"📁{k.ljust(pad)} | {v}" for k, v in tree.items() if v))

# %%
if "step1_installed_flag" not in globals():
  raise Exception("Please run step 1 first!")

from PIL import Image
import os
Image.MAX_IMAGE_PIXELS = None

#@markdown ### 🖼️ Reduce dataset filesize
#@markdown This will convert all images in the project folder to jpeg, reducing filesize without affecting quality too much. This can also solve some errors.
location = images_folder

for dir in [d[0] for d in os.walk(location)]:
    os.chdir(dir)
    converted = False
    for file_name in list(os.listdir(".")):
        try:
            # Convert png to jpeg
            if file_name.endswith(".png"):
                if not converted:
                    print(f"Converting {dir}")
                    converted = True
                im = Image.open(file_name)
                im = im.convert("RGB")
                new_file_name = os.path.splitext(file_name)[0] + ".jpeg"
                im.save(new_file_name, quality=95)
                os.remove(file_name)
                file_name = new_file_name
            # Resize large jpegs
            if file_name.endswith((".jpeg", ".jpg")) and os.path.getsize(file_name) > 2000000:
                if not converted:
                    print(f"Converting {dir}")
                    converted = True
                im = Image.open(file_name)
                im = im.resize((int(im.width/2), int(im.height/2)))
                im.save(file_name, quality=95)
            # Rename jpg to jpeg
            if file_name.endswith(".jpg"):
                if not converted:
                    print(f"Converting {dir}")
                new_file_name = os.path.splitext(file_name)[0] + ".jpeg"
                os.rename(file_name, new_file_name)
        except Exception as e:
            print(f"An error occurred while processing {file_name}: {e}")
    if converted:
        print(f"Converted {dir}")

# %%
if "step1_installed_flag" not in globals():
  raise Exception("Please run step 1 first!")

#@markdown ### 🚮 Clean folder
#@markdown Careful! Deletes all non-image files in the project folder.

# !find {images_folder} -type f ! \( -iname '*.png' -o -iname '*.jpg' -o -iname '*.jpeg' \) -delete
